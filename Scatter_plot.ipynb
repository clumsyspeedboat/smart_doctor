# %% [markdown]
# <a href="https://colab.research.google.com/github/clumsyspeedboat/smart_doctor/blob/main/Scatter_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("owid-covid-data.csv")
#df.plot()  # plots all columns against index
df.plot(kind='scatter',x = 30, y = 40) # scatter plot
df.plot(kind='density')  # estimate density function
df.plot(kind='hist')  # histogram
